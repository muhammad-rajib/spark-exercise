# %% [markdown]
# ### Transform and Apply a function

# %%
import os
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"

import pyspark.pandas as ps

# %%
psdf = ps.DataFrame({'a': range(1, 4), 'b': range(4, 7)})
psdf
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
def pandas_plus(pser):
    return pser + 1 # should always return the same length as input

psdf.transform(pandas_plus)
# Out:
#    a  b
# 0  2  5
# 1  3  6
# 2  4  7

# %%
psdf = ps.DataFrame({'a': range(1, 4), 'b': range(4, 7)})
psdf
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
def pandas_plus(pser):
    return pser[pser % 2 == 1] #always an arbitrary length

psdf.apply(pandas_plus)
# Out:
#      a    b
# 0  1.0  NaN
# 1  NaN  5.0
# 2  3.0  NaN

# %%
psdf = ps.DataFrame({'a': range(1, 4), 'b': range(4, 7)})

def pandas_plus(pser):
    return sum(pser) #allows an arbitrary length

psdf.apply(pandas_plus, axis='columns')
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64
