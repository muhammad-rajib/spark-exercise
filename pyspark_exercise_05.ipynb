# %%
import os
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"

import pyspark.pandas as ps

# %%
import typing
import numpy as np
from pyspark.pandas.typedef import as_spark_type

as_spark_type(int)
# LongType
# Out:
# LongType

# %%
as_spark_type(np.int32)
# IntegerType
# Out:
# IntegerType

# %%
as_spark_type(typing.List[float])
# ArrayType(DoubleType,true)
# Out:
# ArrayType(DoubleType,true)

# %%
ps.Series([0.3, 0.1, 0.8]).spark.data_type
# Out:
# DoubleType

# %%
ps.DataFrame({"d": [0.3, 0.1, 0.8], 
              "s": ["welcome", "to", "pandas-on-Spark"], 
              "b": [False, True, False]}).spark.print_schema()
# Out:
# root
#  |-- d: double (nullable = false)
#  |-- s: string (nullable = false)
#  |-- b: boolean (nullable = false)

# %%
import pandas as pd
import numpy as np
import pyspark.pandas as ps

def sqrt(x):
    return np.sqrt(x)

df = ps.DataFrame([[4, 9]] * 3, columns=['A', 'B'])
df.apply(sqrt, axis=0)
# Out:
#      A    B
# 0  2.0  3.0
# 1  2.0  3.0
# 2  2.0  3.0

# %%
def pandas_div(pdf):
   # pdf is a pandas DataFrame.
   return pdf[['B', 'C']] / pdf[['B', 'C']]

df = ps.DataFrame({'A': ['a', 'a', 'b'], 'B': [1, 2, 3], 'C': [4, 6, 5]})
df.groupby('A').apply(pandas_div)
# Out:
#      B    C
# 0  1.0  1.0
# 1  1.0  1.0
# 2  1.0  1.0

# %%
def transform(pdf) -> pd.DataFrame["id": int, "A": int]:
    pdf['A'] = pdf.id + 1
    return pdf

psdf = ps.range(5).pandas_on_spark.apply_batch(transform)
print(psdf)
psdf.spark.print_schema()
# Out:
# -------------------------------------------------------
# PythonException       Traceback (most recent call last)
# <ipython-input-11-ef848681b73e> in <module>
#       4
#       5 psdf = ps.range(5).pandas_on_spark.apply_batch(transform)
# ----> 6 print(psdf)
#       7 psdf.spark.print_schema()
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\frame.py in __repr__(self)
#   11718             return self._to_internal_pandas().to_string()
#   11719
# > 11720         pdf = self._get_or_create_repr_pandas_cache(max_display_count)
#   11721         pdf_length = len(pdf)
#   11722         pdf = pdf.iloc[:max_display_count]
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\frame.py in _get_or_create_repr_pandas_cache(self, n)
#   11709         if not hasattr(self, "_repr_pandas_cache") or n not in self._repr_pandas_cache:
#   11710             object.__setattr__(
# > 11711                 self, "_repr_pandas_cache", {n: self.head(n + 1)._to_internal_pandas()}
#   11712             )
#   11713         return self._repr_pandas_cache[n]
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\frame.py in _to_internal_pandas(self)
#   11704         This method is for internal use only.
#   11705         """
# > 11706         return self._internal.to_pandas_frame
#   11707
#   11708     def _get_or_create_repr_pandas_cache(self, n: int) -> pd.DataFrame:
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\utils.py in wrapped_lazy_property(self)
#     578     def wrapped_lazy_property(self):
#     579         if not hasattr(self, attr_name):
# --> 580             setattr(self, attr_name, fn(self))
#     581         return getattr(self, attr_name)
#     582
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\internal.py in to_pandas_frame(self)
#    1049         """Return as pandas DataFrame."""
#    1050         sdf = self.to_internal_spark_frame
# -> 1051         pdf = sdf.toPandas()
#    1052         if len(pdf) == 0 and len(sdf.schema) > 0:
#    1053             pdf = pdf.astype(
#
# ~\anaconda3\lib\site-packages\pyspark\sql\pandas\conversion.py in toPandas(self)
#     155
#     156         # Below is toPandas without Arrow optimization.
# --> 157         pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#     158         column_counter = Counter(self.columns)
#     159
#
# ~\anaconda3\lib\site-packages\pyspark\sql\dataframe.py in collect(self)
#     691         """
#     692         with SCCallSiteSync(self._sc) as css:
# --> 693             sock_info = self._jdf.collectToPython()
#     694         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     695
#
# C:\spark\python\lib\py4j-0.10.9-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ~\anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# PythonException:
#   An exception was thrown from the Python worker. Please see the stack trace below.
# Traceback (most recent call last):
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 588, in main
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 336, in read_udfs
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 249, in read_single_udf
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 69, in read_command
#   File "C:\spark\python\lib\pyspark.zip\pyspark\serializers.py", line 160, in _read_with_length
#     return self.loads(obj)
#   File "C:\spark\python\lib\pyspark.zip\pyspark\serializers.py", line 430, in loads
#     return pickle.loads(obj, encoding=encoding)
# ModuleNotFoundError: No module named 'pyspark.pandas'

# %%
import pyspark.pandas as ps
import numpy as np
countries = ['London', 'New York', 'Helsinki']
psser = ps.Series([20., 21., 12.], index=countries)
def square(temperature) -> np.float64:
    assert temperature > 0
    if temperature > 1000:
        temperature = None
    return temperature ** 2
psser.apply(square)
# Out:
# -------------------------------------------------------
# PythonException       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\series.py in __repr__(self)
#    6294             return self._to_internal_pandas().to_string(name=self.name, dtype=self.dtype)
#    6295
# -> 6296         pser = self._psdf._get_or_create_repr_pandas_cache(max_display_count)[self.name]
#    6297         pser_length = len(pser)
#    6298         pser = pser.iloc[:max_display_count]
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\frame.py in _get_or_create_repr_pandas_cache(self, n)
#   11709         if not hasattr(self, "_repr_pandas_cache") or n not in self._repr_pandas_cache:
#   11710             object.__setattr__(
# > 11711                 self, "_repr_pandas_cache", {n: self.head(n + 1)._to_internal_pandas()}
#   11712             )
#   11713         return self._repr_pandas_cache[n]
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\frame.py in _to_internal_pandas(self)
#   11704         This method is for internal use only.
#   11705         """
# > 11706         return self._internal.to_pandas_frame
#   11707
#   11708     def _get_or_create_repr_pandas_cache(self, n: int) -> pd.DataFrame:
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\utils.py in wrapped_lazy_property(self)
#     578     def wrapped_lazy_property(self):
#     579         if not hasattr(self, attr_name):
# --> 580             setattr(self, attr_name, fn(self))
#     581         return getattr(self, attr_name)
#     582
#
# ~\anaconda3\lib\site-packages\pyspark\pandas\internal.py in to_pandas_frame(self)
#    1049         """Return as pandas DataFrame."""
#    1050         sdf = self.to_internal_spark_frame
# -> 1051         pdf = sdf.toPandas()
#    1052         if len(pdf) == 0 and len(sdf.schema) > 0:
#    1053             pdf = pdf.astype(
#
# ~\anaconda3\lib\site-packages\pyspark\sql\pandas\conversion.py in toPandas(self)
#     155
#     156         # Below is toPandas without Arrow optimization.
# --> 157         pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#     158         column_counter = Counter(self.columns)
#     159
#
# ~\anaconda3\lib\site-packages\pyspark\sql\dataframe.py in collect(self)
#     691         """
#     692         with SCCallSiteSync(self._sc) as css:
# --> 693             sock_info = self._jdf.collectToPython()
#     694         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     695
#
# C:\spark\python\lib\py4j-0.10.9-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ~\anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# PythonException:
#   An exception was thrown from the Python worker. Please see the stack trace below.
# Traceback (most recent call last):
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 588, in main
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 447, in read_udfs
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 249, in read_single_udf
#   File "C:\spark\python\lib\pyspark.zip\pyspark\worker.py", line 69, in read_command
#   File "C:\spark\python\lib\pyspark.zip\pyspark\serializers.py", line 160, in _read_with_length
#     return self.loads(obj)
#   File "C:\spark\python\lib\pyspark.zip\pyspark\serializers.py", line 430, in loads
#     return pickle.loads(obj, encoding=encoding)
# ModuleNotFoundError: No module named 'pyspark.pandas'
