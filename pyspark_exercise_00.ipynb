# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Md-Rajib:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv('test1.csv')
df.show()
# Out:
# +------+---+
# |   _c0|_c1|
# +------+---+
# |  Name|Age|
# | Tarek| 23|
# | Forid| 24|
# | Ridoy| 24|
# | Imran| 25|
# |Saiful| 27|
# +------+---+

# %%
df2 = spark.read.option('header', 'true').csv('test1.csv')
df2.show()
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# | Tarek| 23|
# | Forid| 24|
# | Ridoy| 24|
# | Imran| 25|
# |Saiful| 27|
# +------+---+

# %%
type(df2)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df2.head(3)
# Out:
# [Row(Name='Tarek', Age='23'),
#  Row(Name='Forid', Age='24'),
#  Row(Name='Ridoy', Age='24')]

# %%
df2.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
